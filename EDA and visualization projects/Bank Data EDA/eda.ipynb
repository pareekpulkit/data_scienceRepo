# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_rows = 20
pd.options.display.max_columns = 200

# %%
app_data = pd.read_csv('application_data.csv')

# %%
cols = list(app_data.select_dtypes(exclude='object').columns)
app_data0 = app_data[app_data['TARGET']==0]
app_data1 = app_data[app_data['TARGET']==1]
for i in cols:
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.title(f'Probability Distribution of {i}')
    sns.distplot(a=app_data1[i], label='Defaulter - 1 ', hist=False)
    sns.distplot(a=app_data0[i], label='Non Defaulter - 0', hist=False)
    plt.legend()
    plt.subplot(1,2,2)
    sns.boxplot(y = i, x = 'TARGET', data = app_data)
    plt.tight_layout()
    plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
app_data.head(3)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0         351000.0   Unaccompanied          Working
# 1        1129500.0          Family    State servant
# 2         135000.0   Unaccompanied          Working
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0  Secondary / secondary special  Single / not married  House / apartment
# ...

# %%
app_data.info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 122 columns):
#  #    Column                        Non-Null Count   Dtype
# ---   ------                        --------------   -----
#  0    SK_ID_CURR                    307511 non-null  int64
#  1    TARGET                        307511 non-null  int64
#  2    NAME_CONTRACT_TYPE            307511 non-null  object
#  3    CODE_GENDER                   307511 non-null  object
#  4    FLAG_OWN_CAR                  307511 non-null  object
#  5    FLAG_OWN_REALTY               307511 non-null  object
#  6    CNT_CHILDREN                  307511 non-null  int64
#  7    AMT_INCOME_TOTAL              307511 non-null  float64
#  8    AMT_CREDIT                    307511 non-null  float64
#  9    AMT_ANNUITY                   307499 non-null  float64
#  10   AMT_GOODS_PRICE               307233 non-null  float64
#  11   NAME_TYPE_SUITE               306219 non-null  object
# ...

# %%
prev_data = pd.read_csv('previous_application.csv')
prev_data.head(3)
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 0                       15                           Y
# 1                       11                           Y
# 2                       11                           Y
#
#    NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# ...

# %%
prev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %%
col_des = pd.read_csv('columns_description.csv', index_col=0)
col_des
# Out:
#                         Table                        Row  \
# 1            application_data                 SK_ID_CURR
# 2            application_data                     TARGET
# 5            application_data         NAME_CONTRACT_TYPE
# 6            application_data                CODE_GENDER
# 7            application_data               FLAG_OWN_CAR
# ..                        ...                        ...
# 209  previous_application.csv             DAYS_FIRST_DUE
# 210  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 211  previous_application.csv              DAYS_LAST_DUE
# 212  previous_application.csv           DAYS_TERMINATION
# 213  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                            Description  \
# 1                             ID of loan in our sample
# 2    Target variable (1 - client with payment diffi...
# 5          Identification if loan is cash or revolving
# ...

# %%
prev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %%
corr_mat = app_data.corr()

# %%
cnt = 0
for i in app_data['SK_ID_CURR']:
    if i in prev_data['SK_ID_CURR']:
        cnt += 1
print(cnt)
# Out:
# 307511

# %%
# merging both dataset as previous data on applicant would be helpful for credit worthiness in present.
merge_app_prev = app_data.merge(prev_data, on='SK_ID_CURR', how = 'inner',suffixes=('_app','_prev'))

# %%
merge_app_prev.shape
# Out:
# (1413701, 158)

# %%
mis_col = merge_app_prev.isna().mean().reset_index()

# %%
pd.options.display.max_rows = 200
mis_col
# Out:
#                                index             0
# 0                         SK_ID_CURR  0.000000e+00
# 1                             TARGET  0.000000e+00
# 2             NAME_CONTRACT_TYPE_app  0.000000e+00
# 3                        CODE_GENDER  0.000000e+00
# 4                       FLAG_OWN_CAR  0.000000e+00
# 5                    FLAG_OWN_REALTY  0.000000e+00
# 6                       CNT_CHILDREN  0.000000e+00
# 7                   AMT_INCOME_TOTAL  0.000000e+00
# 8                     AMT_CREDIT_app  0.000000e+00
# 9                    AMT_ANNUITY_app  6.578477e-05
# 10               AMT_GOODS_PRICE_app  8.544947e-04
# 11               NAME_TYPE_SUITE_app  2.494162e-03
# 12                  NAME_INCOME_TYPE  0.000000e+00
# 13               NAME_EDUCATION_TYPE  0.000000e+00
# 14                NAME_FAMILY_STATUS  0.000000e+00
# 15                 NAME_HOUSING_TYPE  0.000000e+00
# 16        REGION_POPULATION_RELATIVE  0.000000e+00
# ...

# %%
mis_col = mis_col.rename(mapper={'index':'col_name', 0:'missing'}, axis = 1)

# %%
miss_col1 = list(mis_col[(mis_col['missing']>0.45)]['col_name']) + ['TARGET']

# %%
miss_col_cor = merge_app_prev[miss_col_cor].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9f3b8e92686e> in <module>
# ----> 1 miss_col_cor = merge_app_prev[miss_col_cor].corr()
#
# NameError: name 'miss_col_cor' is not defined

# %%
merge_app_prev.corr()['TARGET'].mean()
# Out:
# 0.00040261015347517085

# %%
miss_col_cor[miss_col_cor['TARGET']>0.0004]['TARGET']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fa8cc8856691> in <module>
# ----> 1 miss_col_cor[miss_col_cor['TARGET']>0.0004]['TARGET']
#
# NameError: name 'miss_col_cor' is not defined

# %%
col1 = list(mis_col[~(mis_col['missing']>0.45)]['col_name'])

# %%
df = merge_app_prev[col1]
df.head(3)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE_app CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1             Cash loans           M            N
# 1      100003       0             Cash loans           F            N
# 2      100003       0             Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_app  \
# 0               Y             0          202500.0        406597.5
# 1               N             0          270000.0       1293502.5
# 2               N             0          270000.0       1293502.5
#
#    AMT_ANNUITY_app  AMT_GOODS_PRICE_app NAME_TYPE_SUITE_app NAME_INCOME_TYPE  \
# 0          24700.5             351000.0       Unaccompanied          Working
# 1          35698.5            1129500.0              Family    State servant
# 2          35698.5            1129500.0              Family    State servant
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# ...

# %%
num_col = list(df.select_dtypes(exclude='object').columns)
obj_col = list(df.select_dtypes(include='object').columns)
id_col = ['SK_ID_CURR','SK_ID_PREV']

# %%
num_cat_col = ['FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL'
               , 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START_app', 'REG_REGION_NOT_LIVE_REGION'
               , 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION','REG_CITY_NOT_LIVE_CITY','REG_CITY_NOT_WORK_CITY'
               , 'LIVE_CITY_NOT_WORK_CITY','FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3','FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6'
               ,'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9','FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12'
               ,'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15','FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18'
               ,'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21','HOUR_APPR_PROCESS_START_prev','NFLAG_LAST_APPL_IN_DAY'
               ,'NFLAG_INSURED_ON_APPROVAL']

# %%
cat_col = obj_col + num_cat_col

# %%
numerical_col = []
for i in num_col:
    if (i not in num_cat_col) and (i not in id_col):
        numerical_col.append(i)

# %%
# not going to use 
cont_num_col = []
dis_num_col = []
for i in numerical_col:
    if df[i].nunique() < 11:
        dis_num_col.append(i)
    else :
        cont_num_col.append(i)
len(cont_num_col), len(dis_num_col)
# Out:
# (30, 7)

# %%
# finding index of columns with less than 1% missing values
def find_mis_idx_1per(data):
    isna_ser = data.isnull().mean()*100
    col_1per = isna_ser[(isna_ser<1) & (isna_ser>0)].index
    idx_list = []
    for i in col_1per:
        idx_sub_list = list(data[data.loc[:,i].isnull()].index)
        idx_list += idx_sub_list
    return set(idx_list)

# %%
idx_mis = find_mis_idx_1per(df)

# %%
df.drop(axis = 0, labels = idx_mis, inplace = True)

# %%
imp_num_col = list(df[numerical_col].columns[df[numerical_col].isnull().mean()*100>0])

# %%
imp_cat_col = list(df[cat_col].columns[df[cat_col].isnull().mean()*100>0])
imp_cat_col
# Out:
# ['OCCUPATION_TYPE', 'NFLAG_INSURED_ON_APPROVAL']

# %%
for i in imp_cat_col:
    print(df[i].value_counts(normalize=True).reset_index())
# Out:
#                     index  OCCUPATION_TYPE
# 0                 MISSING         0.323669
# 1                Laborers         0.177839
# 2             Sales staff         0.107014
# 3              Core staff         0.083595
# 4                Managers         0.067215
# 5                 Drivers         0.059481
# 6   High skill tech staff         0.034307
# 7             Accountants         0.029655
# 8          Medicine staff         0.028284
# 9          Security staff         0.022410
# 10          Cooking staff         0.020299
# 11         Cleaning staff         0.017211
# 12  Private service staff         0.008666
# 13     Low-skill Laborers         0.006609
# 14   Waiters/barmen staff         0.004332
# 15            Secretaries         0.004069
# 16          Realty agents         0.002509
# 17               HR staff         0.001642
# 18               IT staff         0.001195
#      index  NFLAG_INSURED_ON_APPROVAL
# 0      0.0                   0.403675
# ...

# %%
df['OCCUPATION_TYPE'].fillna(value = 'MISSING').isna().sum()

# %%
for i in imp_cat_col:
    df.loc[:,i].fillna(value = 'MISSING', inplace=True)
