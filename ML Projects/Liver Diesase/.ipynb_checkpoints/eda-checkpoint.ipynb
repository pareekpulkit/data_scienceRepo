# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('train_dataset.csv')
data.head()
# Out:
#      ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0  7135    1654     CL  D-penicillamine  19581   F       N            N
# 1  7326      41      C  D-penicillamine  22880   F     NaN            N
# 2  7254     297      D              NaN  27957   F       N            N
# 3  3135    1872      C  D-penicillamine  21111   F     NaN            Y
# 4  2483     939     CL  D-penicillamine  18061   F     NaN          NaN
#
#   Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0       Y     N        0.3        279.0     2.96    84.0    1500.8   99.43
# 1     NaN     N        0.3          NaN     2.96     NaN    1835.4   26.35
# 2     NaN     N        0.3        328.0     2.64     4.0       NaN     NaN
# 3       Y     N        0.3        302.0     2.02    49.0       NaN   26.35
# 4     NaN     N        0.5        344.0     3.11    91.0       NaN  104.56
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             6800 non-null   int64
#  1   N_Days         6800 non-null   int64
#  2   Status         6800 non-null   object
#  3   Drug           4775 non-null   object
#  4   Age            6800 non-null   int64
#  5   Sex            6800 non-null   object
#  6   Ascites        4554 non-null   object
#  7   Hepatomegaly   4373 non-null   object
#  8   Spiders        4210 non-null   object
#  9   Edema          6800 non-null   object
#  10  Bilirubin      6800 non-null   float64
#  11  Cholesterol    3699 non-null   float64
#  12  Albumin        6800 non-null   float64
#  13  Copper         4644 non-null   float64
#  14  Alk_Phos       4302 non-null   float64
#  15  SGOT           4698 non-null   float64
#  16  Tryglicerides  3988 non-null   float64
# ...

# %%
data.describe()
# Out:
#                 ID       N_Days           Age    Bilirubin  Cholesterol  \
# count  6800.000000  6800.000000   6800.000000  6800.000000  3699.000000
# mean   6268.608088  1664.055441  22863.223529     1.806147   294.575831
# std    2405.527133  1332.308135   4671.135682     3.218009   128.085317
# min    1239.000000    41.000000   9598.000000     0.300000   120.000000
# 25%    4353.750000   537.000000  19416.500000     0.300000   204.000000
# 50%    6599.500000  1443.000000  23367.000000     0.400000   312.000000
# 75%    8299.250000  2519.000000  27125.500000     1.800000   353.000000
# max    9999.000000  4795.000000  28650.000000    28.000000  1775.000000
#
#            Albumin       Copper      Alk_Phos         SGOT  Tryglicerides  \
# count  6800.000000  4644.000000   4302.000000  4698.000000    3988.000000
# mean      3.036118    68.569121   1802.951464    79.554427     133.857823
# std       0.528164    59.637733   1618.550339    43.433832      47.291444
# ...

# %%
data.select_dtypes(exclude='object').columns
# Out:
# Index(['ID', 'N_Days', 'Age', 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
#        'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin',
#        'Stage'],
#       dtype='object')

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema'], dtype='object')

# %%
data.groupby('Stage').median()
# Out:
#            ID  N_Days      Age  Bilirubin  Cholesterol  Albumin  Copper  \
# Stage
# 1.0    7157.0  1521.0  23249.0        0.4        305.0    3.020    71.0
# 2.0    6128.0  1365.0  23398.0        0.4        308.0    3.030    68.0
# 3.0    8054.0  1411.0  23518.5        0.4        313.0    3.045    67.0
# 4.0    5538.5  1463.0  23231.5        0.3        314.0    3.000    68.0
#
#        Alk_Phos    SGOT  Tryglicerides  Platelets  Prothrombin
# Stage
# 1.0      1667.8  92.580          130.0      284.0         11.0
# 2.0      1566.5  92.435          129.0      290.0         11.1
# 3.0      1511.9  86.690          128.0      290.0         11.1
# 4.0      1567.1  86.205          127.0      281.0         11.1

# %%
sns.boxplot(data = data, x = 'Stage', y = 'Bilirubin')
# Out:
# <AxesSubplot:xlabel='Stage', ylabel='Bilirubin'>

# %%
sns.countplot(data = data, x = 'Stage', hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Stage', ylabel='count'>

# %% [markdown]
# With Sex Column data seems unbalanced/ or it seems there are more female patients than male for this need to see just male female countplot

# %% [markdown]
# #### Sex Countplot

# %%
sns.countplot(data = data, x = 'Sex')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Data Seems unbalanced

# %% [markdown]
# ## numerical Variables

# %%
num_cols = [ 'Bilirubin', 'Cholesterol', 'Albumin', 'Copper',
       'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets', 'Prothrombin',]
cat_col = ['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema']

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
sns.distplot(data['Bilirubin'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Bilirubin', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Bilirubin', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
sns.distplot(data['Cholesterol'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Cholesterol', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Cholesterol', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
sns.distplot(data['Albumin'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Albumin', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Albumin', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
sns.distplot(data['Copper'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Copper', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Copper', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
sns.distplot(data['Alk_Phos'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Alk_Phos', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Alk_Phos', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
sns.distplot(data['SGOT'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'SGOT', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'SGOT', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
sns.distplot(data['Tryglicerides'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Tryglicerides', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Tryglicerides', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
sns.distplot(data['Platelets'], hist = True)
plt.subplot(1,3,2)
sns.barplot(y = 'Platelets', x = 'Stage', data = data)
plt.subplot(1,3,3)
sns.boxplot(y = 'Platelets', x = 'Stage', data = data)
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,3,1)
sns.distplot(data['Prothrombin'], hist = True)
plt.title('Prothrombin distribution')
plt.subplot(1,3,2)
sns.barplot(y = 'Prothrombin', x = 'Stage', data = data)
plt.title('Prothrombin mean against different stage')
plt.subplot(1,3,3)
sns.boxplot(y = 'Prothrombin', x = 'Stage', data = data)
plt.title('Prothrombin distribution against different stage')
plt.show()

# %% [markdown]
# Findings :
# 1) As stage progresses number of outliers also incresses
# 2) Mean and Median of all variables is similar across all stages
# 3) Here outliers can be important for prediction

# %% [markdown]
# ## Categorical Variables

# %%
cat_col = ['Status', 'Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema']

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Status')
plt.title('Count of Status')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Status', hue = 'Stage')
plt.title('Count of Status across Stage')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Drug')
plt.title('Count of Drug')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Drug', hue = 'Stage')
plt.title('Count of Drug across Stage')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Sex')
plt.title('Count of Sex')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Sex', hue = 'Stage')
plt.title('Count of Sex across Stage')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Ascites')
plt.title('Count of Ascites')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Ascites', hue = 'Stage')
plt.title('Count of Ascites across Stage')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Hepatomegaly')
plt.title('Count of Hepatomegaly')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Hepatomegaly', hue = 'Stage')
plt.title('Count of Hepatomegaly across Stage')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Spiders')
plt.title('Count of Spiders')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Spiders', hue = 'Stage')
plt.title('Count of Spiders across Stage')
plt.show()

# %%
plt.figure(figsize=(18,4))
plt.subplot(1,2,1)
sns.countplot(data=data, x= 'Edema')
plt.title('Count of Edema')
plt.subplot(1,2,2)
sns.countplot(data=data, x = 'Edema', hue = 'Stage')
plt.title('Count of Edema across Stage')
plt.show()

# %% [markdown]
# All categories in cateroical seems to have similar type of trend across different stages of diesase

# %%
sns.pairplot(data = data[num_cols])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),cmap="coolwarm",annot = True)
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
cols_to_keep1 = ['N_Days','Status', 'Drug', 'Age', 'Sex', 'Ascites','Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
       'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets','Prothrombin', 'Stage' ]

# %%
data = data[cols_to_keep1]
data.head(5)
# Out:
#    N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0    1654     CL  D-penicillamine  19581   F       N            N       Y
# 1      41      C  D-penicillamine  22880   F     NaN            N     NaN
# 2     297      D              NaN  27957   F       N            N     NaN
# 3    1872      C  D-penicillamine  21111   F     NaN            Y       Y
# 4     939     CL  D-penicillamine  18061   F     NaN          NaN     NaN
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     N        0.3        279.0     2.96    84.0    1500.8   99.43
# 1     N        0.3          NaN     2.96     NaN    1835.4   26.35
# 2     N        0.3        328.0     2.64     4.0       NaN     NaN
# 3     N        0.3        302.0     2.02    49.0       NaN   26.35
# 4     N        0.5        344.0     3.11    91.0       NaN  104.56
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          109.0      293.0         10.2    4.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   N_Days         6800 non-null   int64
#  1   Status         6800 non-null   object
#  2   Drug           4775 non-null   object
#  3   Age            6800 non-null   int64
#  4   Sex            6800 non-null   object
#  5   Ascites        4554 non-null   object
#  6   Hepatomegaly   4373 non-null   object
#  7   Spiders        4210 non-null   object
#  8   Edema          6800 non-null   object
#  9   Bilirubin      6800 non-null   float64
#  10  Cholesterol    3699 non-null   float64
#  11  Albumin        6800 non-null   float64
#  12  Copper         4644 non-null   float64
#  13  Alk_Phos       4302 non-null   float64
#  14  SGOT           4698 non-null   float64
#  15  Tryglicerides  3988 non-null   float64
#  16  Platelets      6462 non-null   float64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
cont_col_nan = ['Cholesterol','Copper', 'Alk_Phos','SGOT','Tryglicerides','Platelets','Prothrombin']
cat_col_nan = ['Drug', 'Ascites', 'Hepatomegaly', 'Spiders', ]
col_order = data.columns

# %% [markdown]
# Treated : 'Platelets','Prothrombin' with removing those as they were only 7.2% rows

# %%
data.isna().mean()
# Out:
# N_Days           0.000000
# Status           0.000000
# Drug             0.297794
# Age              0.000000
# Sex              0.000000
# Ascites          0.330294
# Hepatomegaly     0.356912
# Spiders          0.380882
# Edema            0.000000
# Bilirubin        0.000000
# Cholesterol      0.456029
# Albumin          0.000000
# Copper           0.317059
# Alk_Phos         0.367353
# SGOT             0.309118
# Tryglicerides    0.413529
# Platelets        0.049706
# Prothrombin      0.022794
# Stage            0.000000
# dtype: float64

# %% [markdown]
# Check where both Platelets and Prothrombin are null

# %%
data[(data['Platelets'].isna()) & (data['Prothrombin'].isna())]
# Out:
#         ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 864   4681     550      D  D-penicillamine  28650   F     NaN            N
# 1082  4994     415      C              NaN  28650   F       N          NaN
# 1425  7809      41      C  D-penicillamine  21030   F       N            N
# 3741  6965    2252     CL              NaN  15851   M       N            N
# 5355  5112    2894      D          Placebo  24965   F       Y          NaN
#
#      Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos   SGOT  \
# 864        N     S        0.3          NaN     3.62     NaN       NaN  26.35
# 1082       N     N        4.1          NaN     3.58     NaN    1827.4  58.53
# 1425       N     N        0.3        289.0     2.86   246.0       NaN    NaN
# 3741     NaN     N        0.3          NaN     2.73     NaN     679.2  36.04
# 5355       N     N        2.6          NaN     2.49     4.0    2014.7    NaN
#
#       Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
data1 = data[~((data['Platelets'].isna()) | (data['Prothrombin'].isna()))]

# %%
data1.isna().sum()
# Out:
# N_Days              0
# Status              0
# Drug             1878
# Age                 0
# Sex                 0
# Ascites          2096
# Hepatomegaly     2233
# Spiders          2400
# Edema               0
# Bilirubin           0
# Cholesterol      2881
# Albumin             0
# Copper           1992
# Alk_Phos         2298
# SGOT             1948
# Tryglicerides    2600
# Platelets           0
# Prothrombin         0
# Stage               0
# dtype: int64

# %% [markdown]
# I think need to check performance of both model how they will react with or without removing rows according to Platelets and Prothrombin
